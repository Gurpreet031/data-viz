# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv("AWCustomers.csv")

# %%
df.head()
# Out:
#    CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0       21173   NaN      Chad          C      Yuan    NaN
# 1       13249   NaN      Ryan        NaN     Perry    NaN
# 2       29350   NaN     Julia        NaN  Thompson    NaN
# 3       13503   NaN  Theodore        NaN     Gomez    NaN
# 4       22803   NaN  Marshall          J      Shan    NaN
#
#              AddressLine1 AddressLine2         City    StateProvinceName  ...  \
# 0      7090 C. Mount Hood          NaN   Wollongong      New South Wales  ...
# 1     3651 Willow Lake Rd          NaN      Shawnee     British Columbia  ...
# 2  1774 Tice Valley Blvd.          NaN  West Covina           California  ...
# 3         2103 Baldwin Dr          NaN    Liverpool              England  ...
# 4         Am Gallberg 234          NaN        Werne  Nordrhein-Westfalen  ...
#
#          Education      Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0        Bachelors        Clerical      M             M             1
# ...

# %%
df['BirthDate'] = pd.to_datetime(df['BirthDate'], errors='coerce')
ref_date = pd.to_datetime("2017-03-06")  # based on LastUpdated column
df['Age'] = (ref_date - df['BirthDate']).dt.days // 36

# %%
selected_columns = [
    'Age', 'Gender', 'MaritalStatus', 'Occupation',
    'HomeOwnerFlag', 'NumberCarsOwned', 'NumberChildrenAtHome',
    'TotalChildren', 'YearlyIncome'
]
df = df[selected_columns]

# %%
df.head()
# Out:
#    Age Gender MaritalStatus      Occupation  HomeOwnerFlag  NumberCarsOwned  \
# 0  297      M             M        Clerical              1                3
# 1  452      M             M        Clerical              1                2
# 2  317      F             S        Clerical              0                3
# 3  399      M             M  Skilled Manual              1                2
# 4  426      M             S  Skilled Manual              1                1
#
#    NumberChildrenAtHome  TotalChildren  YearlyIncome
# 0                     0              1         81916
# 1                     1              2         81076
# 2                     0              0         86387
# 3                     1              2         61481
# 4                     0              0         51804

# %%
dict = {
    'Nominal':['Occupation', 'Gender', 'MaritalStatus', 'Age', 'HomeOwnerFlag'],
    'Discrete':['NumberCarsOwned', 'NumberChildrenAtHome', 'TotalChildren'],
    'Continuous':['YearlyIncome']
}
print(dict)
# Out:
# {'Nominal': ['Occupation', 'Gender', 'MaritalStatus', 'Age', 'HomeOwnerFlag'], 'Discrete': ['NumberCarsOwned', 'NumberChildrenAtHome', 'TotalChildren'], 'Continuous': ['YearlyIncome']}

# %%
sales = pd.read_csv("AWSales.csv")

# %%
sales_df = pd.DataFrame(sales)

# %%
sales_df.head()
# Out:
#    CustomerID  BikeBuyer  AvgMonthSpend
# 0       21173          1          50.97
# 1       13249          1          53.11
# 2       29350          1          54.08
# 3       13503          1          56.93
# 4       22803          1          55.41
